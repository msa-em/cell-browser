# %%
import vizarr
from ipywidgets import GridspecLayout

grid = GridspecLayout(2, 2, height='1000px', width='60%')

# Create viewers
viewer1 = vizarr.Viewer()
viewer1.add_image(
    source='https://barkley-replication.s3.us-east-2.amazonaws.com/experiment1/sample1.zarr/',
)

viewer2 = vizarr.Viewer()
viewer2.add_image(
    source='https://barkley-replication.s3.us-east-2.amazonaws.com/experiment1/sample2.zarr/',
)

viewer3 = vizarr.Viewer()
viewer3.add_image(
    source='https://barkley-replication.s3.us-east-2.amazonaws.com/experiment1/sample3.zarr/',
)

viewer4 = vizarr.Viewer()
viewer4.add_image(
    source='https://barkley-replication.s3.us-east-2.amazonaws.com/experiment1/sample4.zarr/',
)

# Add viewers to grid
grid[0, 0] = viewer1
grid[0, 1] = viewer2
grid[1, 0] = viewer3
grid[1, 1] = viewer4

grid
# Out:
# GridspecLayout(children=(<vizarr._widget.Viewer object at 0x000002405BAFFA10>, <vizarr._widget.Viewer object a…
